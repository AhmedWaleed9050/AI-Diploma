# %% [markdown]
# # Fictitious Names

# %% [markdown]
# ### Introduction:
#
# This time you will create a data again
#
# Special thanks to [Chris Albon](http://chrisalbon.com/) for sharing the dataset and materials.
# All the credits to this exercise belongs to him.
#
# In order to understand about it go [here](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/).
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create the 3 DataFrames based on the following raw data

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# ### Step 3. Assign each to a variable called data1, data2, data3

# %%
data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)

# %% [markdown]
# ### Step 4. Join the two dataframes along rows and assign all_data

# %%
all_data = data1.join(data2, lsuffix='_left', rsuffix='_right')

all_data
# Out:
#   subject_id_left first_name_left last_name_left subject_id_right  \
# 0               1            Alex       Anderson                4
# 1               2             Amy       Ackerman                5
# 2               3           Allen            Ali                6
# 3               4           Alice           Aoni                7
# 4               5          Ayoung        Atiches                8
#
#   first_name_right last_name_right
# 0            Billy          Bonder
# 1            Brian           Black
# 2             Bran         Balwner
# 3            Bryce           Brice
# 4            Betty          Btisan

# %% [markdown]
# ### Step 5. Join the two dataframes along columns and assing to all_data_col

# %%
all_data_col = data1.join(data2, lsuffix='_left', rsuffix='_right')

all_data_col
# Out:
#   subject_id_left first_name_left last_name_left subject_id_right  \
# 0               1            Alex       Anderson                4
# 1               2             Amy       Ackerman                5
# 2               3           Allen            Ali                6
# 3               4           Alice           Aoni                7
# 4               5          Ayoung        Atiches                8
#
#   first_name_right last_name_right
# 0            Billy          Bonder
# 1            Brian           Black
# 2             Bran         Balwner
# 3            Bryce           Brice
# 4            Betty          Btisan

# %% [markdown]
# ### Step 6. Print data3

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# ### Step 7. Merge all_data and data3 along the subject_id value

# %%
if 'subject_id_left' in all_data.columns:
    all_data = all_data.rename(columns={'subject_id_left': 'subject_id'})
# Out:
#   subject_id first_name_left last_name_left subject_id_right first_name_right  \
# 0          1            Alex       Anderson                4            Billy
# 1          2             Amy       Ackerman                5            Brian
# 2          3           Allen            Ali                6             Bran
# 3          4           Alice           Aoni                7            Bryce
# 4          5          Ayoung        Atiches                8            Betty
#
#   last_name_right
# 0          Bonder
# 1           Black
# 2         Balwner
# 3           Brice
# 4          Btisan

# %%
final_data = all_data.merge(data3, on='subject_id', how='outer')
final_data
# Out:
#   subject_id first_name_left last_name_left subject_id_right first_name_right  \
# 0          1            Alex       Anderson                4            Billy
# 1          2             Amy       Ackerman                5            Brian
# 2          3           Allen            Ali                6             Bran
# 3          4           Alice           Aoni                7            Bryce
# 4          5          Ayoung        Atiches                8            Betty
# 5          7             NaN            NaN              NaN              NaN
# 6          8             NaN            NaN              NaN              NaN
# 7          9             NaN            NaN              NaN              NaN
# 8         10             NaN            NaN              NaN              NaN
# 9         11             NaN            NaN              NaN              NaN
#
#   last_name_right  test_id
# 0          Bonder       51
# 1           Black       15
# ...

# %% [markdown]
# ### Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2

# %%
merged_data = data1.merge(data2, on='subject_id', suffixes=('_left', '_right'), how='inner')

merged_data
# Out:
#   subject_id first_name_left last_name_left first_name_right last_name_right
# 0          4           Alice           Aoni            Billy          Bonder
# 1          5          Ayoung        Atiches            Brian           Black

# %% [markdown]
# ### Step 9. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
merged_data = data1.merge(data2, on='subject_id', suffixes=('_left', '_right'), how='outer')

merged_data
# Out:
#   subject_id first_name_left last_name_left first_name_right last_name_right
# 0          1            Alex       Anderson              NaN             NaN
# 1          2             Amy       Ackerman              NaN             NaN
# 2          3           Allen            Ali              NaN             NaN
# 3          4           Alice           Aoni            Billy          Bonder
# 4          5          Ayoung        Atiches            Brian           Black
# 5          6             NaN            NaN             Bran         Balwner
# 6          7             NaN            NaN            Bryce           Brice
# 7          8             NaN            NaN            Betty          Btisan
