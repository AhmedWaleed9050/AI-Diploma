# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv("US_Baby_Names_right.csv" , on_bad_lines='skip')
baby_names
# Out:
# <ipython-input-14-4a634f728be9>:1: DtypeWarning: Columns (0,1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   baby_names = pd.read_csv("US_Baby_Names_right.csv" , on_bad_lines='skip')
#         Unnamed: 0       Id     Name  Year Gender State  Count
# 0            11349    11350     Emma  2004      F    AK   62.0
# 1            11350    11351  Madison  2004      F    AK   48.0
# 2            11351    11352   Hannah  2004      F    AK   46.0
# 3            11352    11353    Grace  2004      F    AK   44.0
# 4            11353    11354    Emily  2004      F    AK   41.0
# ...            ...      ...      ...   ...    ...   ...    ...
# 1078689    5647421  5647422     Seth  2014      M    WY    5.0
# 1078690    5647422  5647423  Spencer  2014      M    WY    5.0
# 1078691    5647423  5647424     Tyce  2014      M    WY    5.0
# 1078692    5647424  5647425   Victor  2014      M    WY    5.0
# 1078693    5647425  5647426   Waylon  2014      M    WY    5.0
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#   Unnamed: 0     Id      Name  Year Gender State  Count
# 0      11349  11350      Emma  2004      F    AK   62.0
# 1      11350  11351   Madison  2004      F    AK   48.0
# 2      11351  11352    Hannah  2004      F    AK   46.0
# 3      11352  11353     Grace  2004      F    AK   44.0
# 4      11353  11354     Emily  2004      F    AK   41.0
# 5      11354  11355   Abigail  2004      F    AK   37.0
# 6      11355  11356    Olivia  2004      F    AK   33.0
# 7      11356  11357  Isabella  2004      F    AK   30.0
# 8      11357  11358    Alyssa  2004      F    AK   29.0
# 9      11358  11359    Sophia  2004      F    AK   28.0

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(columns=['Unnamed: 0', 'Id'] , inplace=True)

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK   62.0
# 1        Madison  2004      F    AK   48.0
# 2         Hannah  2004      F    AK   46.0
# 3          Grace  2004      F    AK   44.0
# 4          Emily  2004      F    AK   41.0
# ...          ...   ...    ...   ...    ...
# 1078689     Seth  2014      M    WY    5.0
# 1078690  Spencer  2014      M    WY    5.0
# 1078691     Tyce  2014      M    WY    5.0
# 1078692   Victor  2014      M    WY    5.0
# 1078693   Waylon  2014      M    WY    5.0
#
# [1078694 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
x = (baby_names['Gender'] == 'F').sum()
print(x)
y = (baby_names['Gender'] == 'M').sum()
print(y)
# Out:
# 587221
# 491471

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.groupby('Name')

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
baby_names['Name'].nunique()
# Out:
# 17634

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
baby_names['Name'].mode()
# Out:
# 0    Riley
# Name: Name, dtype: object

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
names = baby_names.groupby('Name')['Count'].sum()
min_occurrences = names.min()
unique_least_occurrences_count = sum(1 for count in names if count == min_occurrences)
unique_least_occurrences_count
# Out:
# 2

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
name_medians = baby_names.groupby('Name')['Count'].median()
name_medians.median()
# Out:
# 6.0

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
name_std_dev = baby_names.groupby('Name')['Count'].std()
name_std_dev.std()
# Out:
# 29.230465991075185

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
baby_names.groupby('Name')['Count'].describe()
# Out:
#          count       mean        std  min   25%   50%    75%    max
# Name
# Aaban      2.0   6.000000   0.000000  6.0  6.00   6.0   6.00    6.0
# Aadan      5.0   5.600000   0.894427  5.0  5.00   5.0   6.00    7.0
# Aadarsh    1.0   5.000000        NaN  5.0  5.00   5.0   5.00    5.0
# Aaden    210.0  17.395238  20.679856  5.0  6.00  10.0  20.00  158.0
# Aadhav     2.0   6.000000   0.000000  6.0  6.00   6.0   6.00    6.0
# ...        ...        ...        ...  ...   ...   ...    ...    ...
# Zyra       7.0   6.000000   1.154701  5.0  5.00   6.0   6.50    8.0
# Zyrah      2.0   5.500000   0.707107  5.0  5.25   5.5   5.75    6.0
# Zyren      1.0   6.000000        NaN  6.0  6.00   6.0   6.00    6.0
# Zyria     10.0   5.900000   0.737865  5.0  5.25   6.0   6.00    7.0
# Zyriah     9.0   6.444444   1.666667  5.0  5.00   6.0   7.00   10.0
#
# [17634 rows x 8 columns]
